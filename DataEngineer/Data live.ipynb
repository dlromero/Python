# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# # Tipos de datos

# %% [markdown]
# ## Primitivos

# %%
from datetime import datetime

integer_type = 42
float_type = 3.1415
bool_type = False
hex_type = 0xff
oct_type = 0o23
today = datetime.now()
str_type = 'Daniel'

# %% [markdown]
# ## Estructurados

# %%
from IPython.display import Image

Image('mysql_table_example.png')

# %% [markdown]
# ## Semi estructurados

# %%
from IPython.display import Image

Image('html_markup_example.png')

# %% [markdown]
# ## No estructurados
#
# Bello es mejor que feo.
# Explícito es mejor que implícito.
# Simple es mejor que complejo.
# Complejo es mejor que complicado.
# Plano es mejor que anidado.
# Espaciado es mejor que denso.
# La legibilidad es importante.
# Los casos especiales no son lo suficientemente especiales como para romper las reglas.
# Sin embargo la practicidad le gana a la pureza.
# Los errores nunca deberían pasar silenciosamente.
# A menos que se silencien explícitamente.
# Frente a la ambigüedad, evitar la tentación de adivinar.
# Debería haber una, y preferiblemente solo una, manera obvia de hacerlo.
# A pesar de que esa manera no sea obvia a menos que seas Holandés.
# Ahora es mejor que nunca.
# A pesar de que nunca es muchas veces mejor que *ahora* mismo.
# Si la implementación es difícil de explicar, es una mala idea.
# Si la implementación es fácil de explicar, puede que sea una buena idea.
# Los espacios de nombres son una gran idea, ¡tengamos más de esos!

# %%
import requests

response = requests.get("https://platzi.com")

response[dir(response)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-e95537535184> in <module>
#       3 response = requests.get("https://platzi.com")
#       4
# ----> 5 response[dir(response)]
#
# TypeError: 'Response' object is not subscriptable

# %%
print(response.text)
# Out:
#     <!doctype html>
#       <html lang=es-CO>
#         <head>
#           <meta charset="UTF-8">
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <title>ðPlatzi: âCursos Online Profesionales de TecnologÃ­a</title>
#           <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-svg-core@1.2.28/styles.css">
#           <link rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home.be24b7db960f4042d8e6.css" type="text/css" />
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#
# ...

# %% [markdown]
# # Extacción de información HTML

# %%
import bs4

soup = bs4.BeautifulSoup(response.text, 'html.parser')

courses_links = soup.select('.RecentCourses-item a')

courses = [course['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /cursos/curso-de-thick-data
# /cursos/taller-startups-2020
# /cursos/intro-elasticsearch
# /cursos/modelo-3dmaya
# /cursos/intro-selenium
# /cursos/slack
# /cursos/unity-3d
# /cursos/uipath
# /cursos/lenguaje-c
# /cursos/diseno-programadores
# /cursos/excel
# /cursos/bioseguridad-empresas
# /cursos/symfony-framework-2020
# /cursos/prevencion
# /cursos/web-scraping

# %% [markdown]
# # Primera vista al dataset de noticia

# %%
print(soup.select('meta[name=description]')[0]['content'])

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Series

# %%
import pandas as pd

series_test = pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2 = pd.Series({1999: 48, 
                          2000: 65, 
                          2001: 89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# ## DataFrames

# %%
frame_test = pd.DataFrame({1999: [74,38,39], 
                          2000: [34,32,32], 
                          2001: [23,39,23]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2 = pd.DataFrame([[74,38,39], 
                           [34,32,32], 
                           [23,39,23]], columns=[1999,2000,2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# ## Read Data

# %%
pd.options.display.max_rows = 10
el_universal = pd.read_csv('D:\Learning\Platzi\python\webscreapper_curso_data_eng\eluniversal_2020_06_28_articles.csv',
                           encoding= 'utf-8')

el_universal
# Out:
#                                                  body  \
# 0     La Federación Internacional de Patinaje anun...
# 1     Ha sido muy difícil, muy dramático todo esto...
# 2     A 10 asciende la cifra de pacientes muertos ...
# 3     Al hablar de aceites siempre nos enfocamos e...
# 4     Siempre se ocultaron las verdaderas razones ...
# ..                                                ...
# 45    Tras los datos entregados este sábado por el...
# 46    Tras la gestión de la representación estudia...
# 47    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 48    Por estos días, el miedo y la incertidumbre ...
# 49    Desde cuando empezó la cuarentena decretada ...
#
#                                                 title  \
# 0   Mundiales de patinaje de carreras y hockey en ...
# 1   “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2   10 muertos más y 37 nuevos casos de COVID-19 e...
# 3   Aceites naturales o vegetales, fuente inagotab...
# ...

# %% [markdown]
# ## Index and selecion

# %%
# dictionary like

el_universal['title']
# Out:
# 0     Mundiales de patinaje de carreras y hockey en ...
# 1     “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2     10 muertos más y 37 nuevos casos de COVID-19 e...
# 3     Aceites naturales o vegetales, fuente inagotab...
# 4            Federico García Lorca, secretos guardados
#                             ...
# 45    Se reportaron 60 muertes por COVID-19 en el At...
# 46    “Recursos de matrículas son prioritarios para ...
# 47    Video: resumen semanal de noticias con La Reda...
# 48                       UCI, espacio para salvar vidas
# 49    El cáncer no da espera, manejo de pacientes en...
# Name: title, Length: 50, dtype: object

# %%
el_universal[['title','url']]
# Out:
#                                                 title  \
# 0   Mundiales de patinaje de carreras y hockey en ...
# 1   “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2   10 muertos más y 37 nuevos casos de COVID-19 e...
# 3   Aceites naturales o vegetales, fuente inagotab...
# 4          Federico García Lorca, secretos guardados
# ..                                                ...
# 45  Se reportaron 60 muertes por COVID-19 en el At...
# 46  “Recursos de matrículas son prioritarios para ...
# 47  Video: resumen semanal de noticias con La Reda...
# 48                     UCI, espacio para salvar vidas
# 49  El cáncer no da espera, manejo de pacientes en...
#
#                                                   url
# 0   http://www.eluniversal.com.co/deportes/mundial...
# 1   http://www.eluniversal.com.co/suplementos/face...
# 2   http://www.eluniversal.com.co/regional/10-muer...
# 3   http://www.eluniversal.com.co/viernes/aceites-...
# ...

# %%
# Numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  \
# 10    Por ser un padecimiento nuevo en todos los s...
# 11    Un total de 150 líderes y lideresas de la ci...
# 12    Se dice que todos los seres humanos estamos ...
# 13    La sequía del 2019 arrasó con todos los cult...
# 14    Tatiana* no me lo quiso decir la primera vez...
#
#                                                 title  \
# 10                Niños y Covid-19, signos y síntomas
# 11  150 líderes se capacitan para prevenir el COVI...
# 12  Jose Ricardo transforma a Cartagena desde la c...
# 13  Campesinos de San Estanislao piden ayuda al Go...
# 14  La mujer que casi muere por el COVID-19 y por ...
#
#                                                   url
# 10  http://www.eluniversal.com.co/viernes/ninos-y-...
# 11  http://www.eluniversal.com.co/cartagena/150-li...
# 12  http://www.eluniversal.com.co/suplementos/face...
# 13  http://www.eluniversal.com.co/regional/campesi...
# ...

# %%
el_universal.iloc[40]['title']
# Out:
# 'El amor propio, la mejor forma de mantener la salud mental'

# %%
el_universal.iloc[:5,0]
# Out:
# 0      La Federación Internacional de Patinaje anun...
# 1      Ha sido muy difícil, muy dramático todo esto...
# 2      A 10 asciende la cifra de pacientes muertos ...
# 3      Al hablar de aceites siempre nos enfocamos e...
# 4      Siempre se ocultaron las verdaderas razones ...
# Name: body, dtype: object

# %%
el_universal.loc[:,'body':'title']
# Out:
#                                                  body  \
# 0     La Federación Internacional de Patinaje anun...
# 1     Ha sido muy difícil, muy dramático todo esto...
# 2     A 10 asciende la cifra de pacientes muertos ...
# 3     Al hablar de aceites siempre nos enfocamos e...
# 4     Siempre se ocultaron las verdaderas razones ...
# ..                                                ...
# 45    Tras los datos entregados este sábado por el...
# 46    Tras la gestión de la representación estudia...
# 47    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 48    Por estos días, el miedo y la incertidumbre ...
# 49    Desde cuando empezó la cuarentena decretada ...
#
#                                                 title
# 0   Mundiales de patinaje de carreras y hockey en ...
# 1   “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2   10 muertos más y 37 nuevos casos de COVID-19 e...
# 3   Aceites naturales o vegetales, fuente inagotab...
# ...

# %% [markdown]
# ## Data wrangling

# %%
# 1. Añadir newspaper_uid al DataFrame

el_universal['newspaper_uid'] = 'eluniversal'

el_universal
# Out:
#                                                  body  \
# 0     La Federación Internacional de Patinaje anun...
# 1     Ha sido muy difícil, muy dramático todo esto...
# 2     A 10 asciende la cifra de pacientes muertos ...
# 3     Al hablar de aceites siempre nos enfocamos e...
# 4     Siempre se ocultaron las verdaderas razones ...
# ..                                                ...
# 45    Tras los datos entregados este sábado por el...
# 46    Tras la gestión de la representación estudia...
# 47    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 48    Por estos días, el miedo y la incertidumbre ...
# 49    Desde cuando empezó la cuarentena decretada ...
#
#                                                 title  \
# 0   Mundiales de patinaje de carreras y hockey en ...
# 1   “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2   10 muertos más y 37 nuevos casos de COVID-19 e...
# 3   Aceites naturales o vegetales, fuente inagotab...
# ...

# %%
# 1. Obtner el host
from urllib.parse import urlparse

el_universal['host'] = el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                  body  \
# 0     La Federación Internacional de Patinaje anun...
# 1     Ha sido muy difícil, muy dramático todo esto...
# 2     A 10 asciende la cifra de pacientes muertos ...
# 3     Al hablar de aceites siempre nos enfocamos e...
# 4     Siempre se ocultaron las verdaderas razones ...
# ..                                                ...
# 45    Tras los datos entregados este sábado por el...
# 46    Tras la gestión de la representación estudia...
# 47    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 48    Por estos días, el miedo y la incertidumbre ...
# 49    Desde cuando empezó la cuarentena decretada ...
#
#                                                 title  \
# 0   Mundiales de patinaje de carreras y hockey en ...
# 1   “Ha sido muy difícil todo esto”: dueños del ‘m...
# 2   10 muertos más y 37 nuevos casos de COVID-19 e...
# 3   Aceites naturales o vegetales, fuente inagotab...
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.co    50
# Name: host, dtype: int64

# %% [markdown]
# ## Missing data

# %%
#3. Rellenar datos faltantes

missing_titles_mask = el_universal['title'].isna()

missing_titles = (el_universal[missing_titles_mask]['url']
                         .str.extract(r'(?P<missing_titles>[^/]+)$')
                         .applymap(lambda title: title.split('-'))
                         .applymap(lambda title_world_list: ' '.join(title_world_list))
                  )
missing_titles
# Out:
# Empty DataFrame
# Columns: [missing_titles]
# Index: []

# %%
el_universal.loc[missing_titles_mask, 'title'] = missing_titles.loc[:, 'missing_titles']

# %% [markdown]
# ## Additional cleanup

# %%
#4. Añadir uid a las filas
import hashlib

uids= (el_universal
           .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
           .apply(lambda hash_object: hash_object.hexdigest())        
        )
el_universal['uid'] = uids
el_universal.set_index('uid',inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# 413ce5a4a76471304e42d2524e8465ca    La Federación Internacional de Patinaje anun...
# f50b609a07325659c8b54393ea23b86b    Ha sido muy difícil, muy dramático todo esto...
# 55bb823472597713d1b812e7cf4a5b18    A 10 asciende la cifra de pacientes muertos ...
# fad1a06882dc69c188fb8ac6ed5a59d8    Al hablar de aceites siempre nos enfocamos e...
# cae57a422b5fbd4b2ba2b82030b682cc    Siempre se ocultaron las verdaderas razones ...
# ...                                                                             ...
# adb01c377fcd26c0dc10c6a8874da238    Tras los datos entregados este sábado por el...
# 7b14b5d245dcfe7ad52ee8238cb5cdfb    Tras la gestión de la representación estudia...
# e644f1ab975637225432f4e5f8f1248a    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 5c812f7061c956052e6b1ee70261b2ca    Por estos días, el miedo y la incertidumbre ...
# ...

# %%
stripped_body =(el_universal
                   .apply(lambda row: row['body'],axis=1)
                   .apply(lambda body: list(body))
                   .apply(lambda letters: list(map(lambda letter: letter.replace('\n', ''),letters)))
                   .apply(lambda letters: ''.join(letters))
               )
stripped_body
# Out:
# uid
# 413ce5a4a76471304e42d2524e8465ca      La Federación Internacional de Patinaje anun...
# f50b609a07325659c8b54393ea23b86b      Ha sido muy difícil, muy dramático todo esto...
# 55bb823472597713d1b812e7cf4a5b18      A 10 asciende la cifra de pacientes muertos ...
# fad1a06882dc69c188fb8ac6ed5a59d8      Al hablar de aceites siempre nos enfocamos e...
# cae57a422b5fbd4b2ba2b82030b682cc      Siempre se ocultaron las verdaderas razones ...
#                                                           ...
# adb01c377fcd26c0dc10c6a8874da238      Tras los datos entregados este sábado por el...
# 7b14b5d245dcfe7ad52ee8238cb5cdfb      Tras la gestión de la representación estudia...
# e644f1ab975637225432f4e5f8f1248a      ¿Aquarela será demolido? ¿Por qué se fue la ...
# 5c812f7061c956052e6b1ee70261b2ca      Por estos días, el miedo y la incertidumbre ...
# 81b2ced41fc47e221eb264bf75b4f4ea      Desde cuando empezó la cuarentena decretada ...
# Length: 50, dtype: object

# %% [markdown]
# ## Data enrichment

# %%
#6 tokenizar el titulo y el body
import nltk
from nltk.corpus import stopwords

# nltk.download('punkt')
# nltk.download('stopwords')

stop_words = set(stopwords.words('spanish'))

def tokenize_column(df,column_name):
    return (df
            .dropna()
            .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
            .apply(lambda tokens: list(filter(lambda token: token.isalpha(),tokens)))
            .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
            .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
            .apply(lambda valid_word_list: len(valid_word_list) )
           )

el_universal['n_tokens_title'] = tokenize_column(el_universal, 'title')
el_universal['n_tokens_body'] = tokenize_column(el_universal, 'body')
el_universal
# Out:
#                                                                                body  \
# uid
# 413ce5a4a76471304e42d2524e8465ca    La Federación Internacional de Patinaje anun...
# f50b609a07325659c8b54393ea23b86b    Ha sido muy difícil, muy dramático todo esto...
# 55bb823472597713d1b812e7cf4a5b18    A 10 asciende la cifra de pacientes muertos ...
# fad1a06882dc69c188fb8ac6ed5a59d8    Al hablar de aceites siempre nos enfocamos e...
# cae57a422b5fbd4b2ba2b82030b682cc    Siempre se ocultaron las verdaderas razones ...
# ...                                                                             ...
# adb01c377fcd26c0dc10c6a8874da238    Tras los datos entregados este sábado por el...
# 7b14b5d245dcfe7ad52ee8238cb5cdfb    Tras la gestión de la representación estudia...
# e644f1ab975637225432f4e5f8f1248a    ¿Aquarela será demolido? ¿Por qué se fue la ...
# 5c812f7061c956052e6b1ee70261b2ca    Por estos días, el miedo y la incertidumbre ...
# ...

# %% [markdown]
# ## Duplicate values

# %%
# 8. Eliminar duplicados
el_universal['title'].value_counts()
# Out:
# La mujer que casi muere por el COVID-19 y por las mentiras de las redes        2
# UCI, espacio para salvar vidas                                                 2
# Las estadísticas de COVID-19 en Sucre siguen en ascenso                        1
# Un muerto, un lesionado y dos capturados dejó una riña en La Perimetral        1
# “Recursos de matrículas son prioritarios para estratos 1 y 2”: Mineducación    1
#                                                                               ..
# ¿Desde cuándo hay que comenzar a cuidar el corazón?                            1
# La causa sobre dopaje tecnológico, archivada por falta de pruebas              1
# La anemia de células falciformes, una enfermedad olvidada                      1
# Libro digital para informar sobre el coronavirus                               1
# 10 muertos más y 37 nuevos casos de COVID-19 en Córdoba                        1
# Name: title, Length: 48, dtype: int64

# %%
el_universal[el_universal['title'] == 'La mujer que casi muere por el COVID-19 y por las mentiras de las redes']
# Out:
#                                                                                body  \
# uid
# db6a907886c14076ecf0605d2212ae6e    Tatiana* no me lo quiso decir la primera vez...
# 03ed257160ad415ca3dd043b14aa4c93              jun 28 - 09:00    La mujer que cas...
#
#                                                                               title  \
# uid
# db6a907886c14076ecf0605d2212ae6e  La mujer que casi muere por el COVID-19 y por ...
# 03ed257160ad415ca3dd043b14aa4c93  La mujer que casi muere por el COVID-19 y por ...
#
#                                                                                 url  \
# uid
# db6a907886c14076ecf0605d2212ae6e  http://www.eluniversal.com.co/suplementos/face...
# 03ed257160ad415ca3dd043b14aa4c93  http://www.eluniversal.com.co/suplementos/facetas
#
#                                  newspaper_uid                    host  \
# uid
# db6a907886c14076ecf0605d2212ae6e   eluniversal  www.eluniversal.com.co
# ...

# %%
el_universal.drop_duplicates(subset=['title'],keep='first',inplace=True)

# %%
# Tabla final
el_universal
# Out:
#                                                                                body  \
# uid
# 413ce5a4a76471304e42d2524e8465ca    La Federación Internacional de Patinaje anun...
# f50b609a07325659c8b54393ea23b86b    Ha sido muy difícil, muy dramático todo esto...
# 55bb823472597713d1b812e7cf4a5b18    A 10 asciende la cifra de pacientes muertos ...
# fad1a06882dc69c188fb8ac6ed5a59d8    Al hablar de aceites siempre nos enfocamos e...
# cae57a422b5fbd4b2ba2b82030b682cc    Siempre se ocultaron las verdaderas razones ...
# ...                                                                             ...
# 9efd788e96db9627380b231967964d41    Wilson Ortega, un comerciante informal de Ca...
# adb01c377fcd26c0dc10c6a8874da238    Tras los datos entregados este sábado por el...
# 7b14b5d245dcfe7ad52ee8238cb5cdfb    Tras la gestión de la representación estudia...
# e644f1ab975637225432f4e5f8f1248a    ¿Aquarela será demolido? ¿Por qué se fue la ...
# ...

# %% [markdown]
# ## Descriptive analysis

# %%
clean_eluniversal = pd.read_csv('D:\Learning\Platzi\python\Webscreapper\eluniversal_2020_06_28_articles_clean.csv')
clean_elpais = pd.read_csv('D:\Learning\Platzi\python\Webscreapper\elpais_2020_06_28_articles_clean.csv')

# %%
clean_eluniversal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       48.000000      48.000000
# mean         5.062500     327.625000
# std          1.507517     208.082903
# min          1.000000       0.000000
# 25%          4.000000     156.000000
# 50%          5.000000     289.000000
# 75%          6.000000     467.750000
# max          8.000000     950.000000

# %%
clean_elpais.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       41.000000      41.000000
# mean         7.292683      64.536585
# std          1.631623      49.706186
# min          2.000000      13.000000
# 25%          6.000000      22.000000
# 50%          8.000000      54.000000
# 75%          8.000000      94.000000
# max         10.000000     219.000000

# %%
clean_elpais['n_tokens_title'].plot(style='k.')
clean_eluniversal['n_tokens_title'].plot(style='r.')

# %%
clean_elpais['n_tokens_body'].plot(style='k.')
clean_eluniversal['n_tokens_body'].plot(style='r.')

# %%
all_newspapers = pd.concat([clean_eluniversal, clean_elpais])
grouped = all_newspapers.groupby('newspapper_uid')

grouped.hist()
# Out:
# newspapper_uid
# D:\Learning\Platzi\python\Webscreapper\elpais         [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# D:\Learning\Platzi\python\Webscreapper\eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                                                     min        mean  max
# newspapper_uid
# D:\Learning\Platzi\python\Webscreapper\elpais        13   64.536585  219
# D:\Learning\Platzi\python\Webscreapper\eluniversal    0  327.625000  950

# %%
grouped.plot()
# Out:
# newspapper_uid
# D:\Learning\Platzi\python\Webscreapper\elpais         AxesSubplot(0.125,0.125;0.775x0.755)
# D:\Learning\Platzi\python\Webscreapper\eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
